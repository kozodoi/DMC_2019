# %% [markdown]
# # 1. SETTINGS

# %%
# import packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import lightgbm as lgb
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import RobustScaler
from sklearn.decomposition import PCA, FastICA, FactorAnalysis
from sklearn.metrics import log_loss
import copy
import scipy.stats
import os
import time
import pandas as pd

# %%
# helper functions
import functions
from functions import *

# %%
# pandas options
pd.set_option('display.max_columns', None)

# %%
# dark background style
plt.style.use('dark_background')

# %%
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# garbage collection
import gc
gc.enable()

# %% [markdown]
# # 2. DATA PREPARATION

# %%
# import CSV
df = pd.read_csv('../data/data_v3.csv')
print(df.shape)
# Out:
# (500000, 13)

# %%
# target variable
target = 'fraud'

# %%
# partitioning
train = df[df[target].isnull() == False]
test  = df[df[target].isnull() == True]
print(train.shape)
print(test.shape)
# Out:
# (1879, 13)
# (498121, 13)

# %%
# target variable
y = train[target]
del train[target], test[target]

# %% [markdown]
# # 3. MODELING

# %% [markdown]
# ### PARAMETERS

# %%
# drop bad features
excluded_feats = ['id']
features = [f for f in train.columns if f not in excluded_feats]
print(train[features].shape)
# Out:
# (1879, 11)

# %%
### PARAMETERS

# settings
cores = 12
seed  = 23

# cross-validation
num_folds = 5
shuffle   = True

# muner of rounds
max_rounds = 600
stopping   = 600
verbose    = 200

# LGB parameters
lgb_params = {
    'boosting_type':     'gbdt',
    'objective':         'binary',
    'metrics':           'binary_logloss',
    'bagging_fraction':  0.9,
    'feature_fraction':  0.8,
    'lambda_l1':         0.1,
    'lambda_l2':         0.1,
    'min_split_gain':    0.01,
    'min_child_weight':  2,
    'min_child_samples': 20,
    'silent':            True,
    'verbosity':         -1,
    'learning_rate':     0.1,
    'max_depth':         7,
    'num_leaves':        70,
    'scale_pos_weight':  1,
    'n_estimators':      max_rounds,
    'nthread' :          cores,
    'random_state':      seed,
}
# data partitinoing
folds = StratifiedKFold(n_splits = num_folds, random_state = seed, shuffle = shuffle)

# %%
# placeholders
clfs = []
valid_profit = np.zeros(num_folds) 
preds_test   = np.zeros(test.shape[0])
preds_oof    = np.zeros(train.shape[0])
importances  = pd.DataFrame()

# %%
# SMOTE settings
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTEENN
sm = SMOTE(random_state = 23, n_jobs = 10, sampling_strategy = 0.1)
sm2 = SMOTEENN(smote=sm)

# %% [markdown]
# ### CROSS-VALIDATION

# %%
from sklearn.model_selection import RandomizedSearchCV
from imblearn.pipeline import make_pipeline
from collections.abc import Iterable
from sklearn.metrics import make_scorer

qs = [0,100]
scaler_params = {
    #'quantile_range': [(qs[0],i) for i in np.arange(0,101) if i > qs[0]],
    'quantile_range': [(i,qs[1]) for i in np.arange(0,101,5) if i < qs[1]],
    #'quantile_range': [(qs[0],i) for i in np.arange(qs[1]-5,qs[1]+5,0.1) if i > qs[0]],
    #'quantile_range': [(i,qs[1]) for i in np.arange(qs[0]-5,qs[0]+5,0.1) if i < qs[1]],
    #'with_centering': [True,False],
#    'with_scaling': [True,False]
}
params = dict()
params.update({'lgbmclassifier__'+k: v if isinstance(v,Iterable) and not isinstance(v,str) else [v] for k,v in lgb_params.items()})
params.update({'robustscaler__'+k:   v if isinstance(v,Iterable) else [v] for k,v in scaler_params.items()})

lgb.LGBMClassifier()
rs = RandomizedSearchCV(
    estimator = make_pipeline(RobustScaler(),sm2,lgb.LGBMClassifier(objective = custom_loss
                                                           )),
    n_iter = 100,
    param_distributions = params,
    #scoring=make_scorer(prediction_reward,greater_is_better=True), 
    cv=num_folds, 
    n_jobs=cores,
    verbose=2)
rs.fit(train[features],y,lgbmclassifier__eval_metric = prediction_reward)
# Out:
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [Parallel(n_jobs=12)]: Using backend LokyBackend with 12 concurrent workers.
# [Parallel(n_jobs=12)]: Done   5 out of  10 | elapsed:    4.2s remaining:    4.2s
# [Parallel(n_jobs=12)]: Done  10 out of  10 | elapsed:    5.0s finished
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#           estimator=Pipeline(memory=None,
#      steps=[('robustscaler', RobustScaler(copy=True, quantile_range=(25.0, 75.0), with_centering=True,
#        with_scaling=True)), ('smoteenn', SMOTEENN(enn=None, random_state=None, ratio=None, sampling_strategy='auto',
#      smote=SMOTE(k_neighbors=5, kind='deprecated', m_neighbors='deprecated', n_jobs=1...0, reg_lambda=0.0, silent=True,
#         subsample=1.0, subsample_for_bin=200000, subsample_freq=0))]),
#           fit_params=None, iid='warn', n_iter=2, n_jobs=12,
#           param_distributions={'lgbmclassifier__boosting_type': ['gbdt'], 'lgbmclassifier__objective': ['binary'], 'lgbmclassifier__metrics': ['binary_logloss'], 'lgbmclassifier__bagging_fraction': [0.9], 'lgbmclassifier__feature_fraction': [0.8], 'lgbmclassifier__lambda_l1': [0.1], 'lgbmclassifier__lambda_l2... (55, 100), (60, 100), (65, 100), (70, 100), (75, 100), (80, 100), (85, 100), (90, 100), (95, 100)]},
#           pre_dispatch='2*n_jobs', random_state=None, refit=True,
#           return_train_score='warn', scoring=None, verbose=2)

# %%
lgb_params_star = {k.replace('lgbmclassifier__',''):v for k,v in rs.best_params_.items() if 'lgbmclassifier' in k}
print(rs.best_score_)
#lgb_params = lgb_params_star
# Out:
# 0.9856306546035125

# %%
sorted(rs.estimator.get_params().keys())
# Out:
# ['lgbmclassifier',
#  'lgbmclassifier__boosting_type',
#  'lgbmclassifier__class_weight',
#  'lgbmclassifier__colsample_bytree',
#  'lgbmclassifier__importance_type',
#  'lgbmclassifier__learning_rate',
#  'lgbmclassifier__max_depth',
#  'lgbmclassifier__min_child_samples',
#  'lgbmclassifier__min_child_weight',
#  'lgbmclassifier__min_split_gain',
#  'lgbmclassifier__n_estimators',
#  'lgbmclassifier__n_jobs',
#  'lgbmclassifier__num_leaves',
#  'lgbmclassifier__objective',
#  'lgbmclassifier__random_state',
#  'lgbmclassifier__reg_alpha',
#  'lgbmclassifier__reg_lambda',
#  'lgbmclassifier__silent',
#  'lgbmclassifier__subsample',
#  'lgbmclassifier__subsample_for_bin',
#  'lgbmclassifier__subsample_freq',
#  'memory',
#  'robustscaler',
#  'robustscaler__copy',
#  'robustscaler__quantile_range',
#  'robustscaler__with_centering',
#  'robustscaler__with_scaling',
#  'smoteenn',
#  'smoteenn__enn',
#  'smoteenn__random_state',
#  'smoteenn__ratio',
#  'smoteenn__sampling_strategy',
#  'smoteenn__smote',
#  'smoteenn__smote__k_neighbors',
#  'smoteenn__smote__kind',
#  'smoteenn__smote__m_neighbors',
#  'smoteenn__smote__n_jobs',
#  'smoteenn__smote__out_step',
#  'smoteenn__smote__random_state',
#  'smoteenn__smote__ratio',
#  'smoteenn__smote__sampling_strategy',
#  'smoteenn__smote__svm_estimator',
#  'steps']

# %%
[i for i in rs.estimator.get_params().keys() if 'eval' in i]
#{k:v for k,v in lgb_params.items() if k in list(rs.estimator.get_params().keys())}
# Out:
# []

# %%
### CROSS-VALIDATION LOOP
for n_fold, (trn_idx, val_idx) in enumerate(folds.split(train, y)):
    
    # data partitioning
    trn_x, trn_y = train[features].iloc[trn_idx], y.iloc[trn_idx]
    val_x, val_y = train[features].iloc[val_idx], y.iloc[val_idx]
    
    # scale data
    scaler   = RobustScaler()
    trn_x    = pd.DataFrame(scaler.fit_transform(trn_x),      columns = features)
    val_x    = pd.DataFrame(scaler.transform(val_x),          columns = features)
    tmp_test = pd.DataFrame(scaler.transform(test[features]), columns = features)

    # augment training data with SMOTE
    trn_x, trn_y = sm.fit_sample(trn_x, trn_y)
    trn_x = pd.DataFrame(trn_x, columns = features)
    trn_y = pd.Series(trn_y)
    
    # factor decomposition
    tmp_features = copy.deepcopy(features)
    
    # train lightGBM
    print('Custom early stopping: select the best out of %.0f iterations...' % max_rounds)
    clf = lgb.LGBMClassifier(**lgb_params)
    #clf.set_params(**{'objective': custom_loss})
    clf = clf.fit(trn_x, trn_y, 
                  eval_set              = [(trn_x, trn_y), (val_x, val_y)], 
                  eval_metric           = prediction_reward, 
                  #eval_metric           = "logloss", 
                  #early_stopping_rounds = stopping,
                  verbose               = verbose
                 )
    clfs.append(clf)
    
    # find the best iteration
    best_iter = np.argmax(clf.evals_result_['valid_1']['profit']) + 1

    # predictions
    preds_oof[val_idx]    = clf.predict_proba(val_x, num_iteration = best_iter)[:, 1]
    valid_profit[n_fold]  = prediction_reward(val_y, preds_oof[val_idx])[1]
    preds_test           += clf.predict_proba(tmp_test, num_iteration = best_iter)[:, 1] / folds.n_splits 

    ## importance
    fold_importance_df = pd.DataFrame()
    fold_importance_df['Feature'] = tmp_features
    fold_importance_df['Importance'] = clf.feature_importances_
    fold_importance_df['Fold'] = n_fold + 1
    importances = pd.concat([importances, fold_importance_df], axis = 0)
    
    # print performance
    print('--------------------------------')
    print('FOLD%2d: PROFIT = %.0f' % (n_fold + 1, valid_profit[n_fold]))
    print('--------------------------------')
    print('')
    
    # clear memory
    del trn_x, trn_y, val_x, val_y
    gc.collect()
    
    # uncomment for mean target encoding
    #features = [f for f in train.columns if f not in excluded_feats]
    
    
# print overall performance    
cv_perf = np.sum(valid_profit)
print('--------------------------------')
print('TOTAL PROFIT = %.0f' % cv_perf)
print('--------------------------------')
# Out:
# Custom early stopping: select the best out of 600 iterations...
# [1]	training's binary_logloss: 0.231828	training's profit: -710	valid_1's binary_logloss: 0.181446	valid_1's profit: -105
# [2]	training's binary_logloss: 0.212174	training's profit: -710	valid_1's binary_logloss: 0.17436	valid_1's profit: -105
# [3]	training's binary_logloss: 0.196823	training's profit: -710	valid_1's binary_logloss: 0.169997	valid_1's profit: -105
# [4]	training's binary_logloss: 0.172281	training's profit: -710	valid_1's binary_logloss: 0.152349	valid_1's profit: -105
# [5]	training's binary_logloss: 0.156713	training's profit: -590	valid_1's binary_logloss: 0.140714	valid_1's profit: -105
# [6]	training's binary_logloss: 0.146682	training's profit: -510	valid_1's binary_logloss: 0.136586	valid_1's profit: -85
# [7]	training's binary_logloss: 0.13198	training's profit: -100	valid_1's binary_logloss: 0.124621	valid_1's profit: -85
# [8]	training's binary_logloss: 0.119661	training's profit: 90	valid_1's binary_logloss: 0.114056	valid_1's profit: -45
# [9]	training's binary_logloss: 0.109115	training's profit: 260	valid_1's binary_logloss: 0.105747	valid_1's profit: -15
# [10]	training's binary_logloss: 0.0993172	training's profit: 340	valid_1's binary_logloss: 0.0970359	valid_1's profit: 5
# [11]	training's binary_logloss: 0.0914744	training's profit: 355	valid_1's binary_logloss: 0.0906373	valid_1's profit: 15
# [12]	training's binary_logloss: 0.0842113	training's profit: 435	valid_1's binary_logloss: 0.0844588	valid_1's profit: 15
# [13]	training's binary_logloss: 0.0804625	training's profit: 465	valid_1's binary_logloss: 0.0827143	valid_1's profit: 15
# [14]	training's binary_logloss: 0.0760546	training's profit: 495	valid_1's binary_logloss: 0.0806514	valid_1's profit: 15
# [15]	training's binary_logloss: 0.0708831	training's profit: 495	valid_1's binary_logloss: 0.0754216	valid_1's profit: 25
# [16]	training's binary_logloss: 0.0657132	training's profit: 545	valid_1's binary_logloss: 0.0713415	valid_1's profit: 25
# [17]	training's binary_logloss: 0.0624836	training's profit: 545	valid_1's binary_logloss: 0.0691442	valid_1's profit: 35
# [18]	training's binary_logloss: 0.0586467	training's profit: 555	valid_1's binary_logloss: 0.0654493	valid_1's profit: 45
# [19]	training's binary_logloss: 0.0560563	training's profit: 575	valid_1's binary_logloss: 0.0645103	valid_1's profit: 45
# [20]	training's binary_logloss: 0.0521188	training's profit: 585	valid_1's binary_logloss: 0.0601646	valid_1's profit: 65
# [21]	training's binary_logloss: 0.0487472	training's profit: 625	valid_1's binary_logloss: 0.0571365	valid_1's profit: 65
# [22]	training's binary_logloss: 0.0461445	training's profit: 635	valid_1's binary_logloss: 0.0549249	valid_1's profit: 65
# [23]	training's binary_logloss: 0.0432838	training's profit: 645	valid_1's binary_logloss: 0.0527431	valid_1's profit: 75
# [24]	training's binary_logloss: 0.0409539	training's profit: 665	valid_1's binary_logloss: 0.0503697	valid_1's profit: 75
# [25]	training's binary_logloss: 0.0389033	training's profit: 665	valid_1's binary_logloss: 0.0483724	valid_1's profit: 85
# [26]	training's binary_logloss: 0.0364114	training's profit: 665	valid_1's binary_logloss: 0.0460843	valid_1's profit: 85
# [27]	training's binary_logloss: 0.0348318	training's profit: 665	valid_1's binary_logloss: 0.0451153	valid_1's profit: 85
# [28]	training's binary_logloss: 0.0334492	training's profit: 665	valid_1's binary_logloss: 0.0442392	valid_1's profit: 85
# [29]	training's binary_logloss: 0.0319576	training's profit: 665	valid_1's binary_logloss: 0.0433559	valid_1's profit: 95
# [30]	training's binary_logloss: 0.0307881	training's profit: 665	valid_1's binary_logloss: 0.0432327	valid_1's profit: 95
# [31]	training's binary_logloss: 0.0296021	training's profit: 675	valid_1's binary_logloss: 0.0423717	valid_1's profit: 95
# [32]	training's binary_logloss: 0.0285309	training's profit: 675	valid_1's binary_logloss: 0.0422037	valid_1's profit: 85
# [33]	training's binary_logloss: 0.0273312	training's profit: 675	valid_1's binary_logloss: 0.0407121	valid_1's profit: 85
# [34]	training's binary_logloss: 0.0259844	training's profit: 675	valid_1's binary_logloss: 0.0388576	valid_1's profit: 85
# [35]	training's binary_logloss: 0.024803	training's profit: 675	valid_1's binary_logloss: 0.0374769	valid_1's profit: 95
# [36]	training's binary_logloss: 0.02363	training's profit: 675	valid_1's binary_logloss: 0.0364832	valid_1's profit: 95
# [37]	training's binary_logloss: 0.0229582	training's profit: 685	valid_1's binary_logloss: 0.0362845	valid_1's profit: 95
# [38]	training's binary_logloss: 0.022167	training's profit: 685	valid_1's binary_logloss: 0.0352342	valid_1's profit: 95
# [39]	training's binary_logloss: 0.0212236	training's profit: 685	valid_1's binary_logloss: 0.0339707	valid_1's profit: 95
# [40]	training's binary_logloss: 0.0204483	training's profit: 685	valid_1's binary_logloss: 0.033233	valid_1's profit: 95
# [41]	training's binary_logloss: 0.0198928	training's profit: 685	valid_1's binary_logloss: 0.0330281	valid_1's profit: 95
# [42]	training's binary_logloss: 0.0190955	training's profit: 685	valid_1's binary_logloss: 0.0319353	valid_1's profit: 95
# [43]	training's binary_logloss: 0.0183613	training's profit: 685	valid_1's binary_logloss: 0.0311339	valid_1's profit: 95
# [44]	training's binary_logloss: 0.0176701	training's profit: 685	valid_1's binary_logloss: 0.0305583	valid_1's profit: 95
# [45]	training's binary_logloss: 0.017238	training's profit: 685	valid_1's binary_logloss: 0.0306745	valid_1's profit: 95
# [46]	training's binary_logloss: 0.0166673	training's profit: 685	valid_1's binary_logloss: 0.0299586	valid_1's profit: 95
# [47]	training's binary_logloss: 0.0161685	training's profit: 710	valid_1's binary_logloss: 0.0295196	valid_1's profit: 95
# [48]	training's binary_logloss: 0.0158114	training's profit: 710	valid_1's binary_logloss: 0.0294685	valid_1's profit: 95
# [49]	training's binary_logloss: 0.0152892	training's profit: 710	valid_1's binary_logloss: 0.0285203	valid_1's profit: 95
# [50]	training's binary_logloss: 0.0149227	training's profit: 710	valid_1's binary_logloss: 0.0278556	valid_1's profit: 95
# [51]	training's binary_logloss: 0.0145158	training's profit: 710	valid_1's binary_logloss: 0.0275738	valid_1's profit: 95
# [52]	training's binary_logloss: 0.0142247	training's profit: 710	valid_1's binary_logloss: 0.0271096	valid_1's profit: 95
# [53]	training's binary_logloss: 0.0139702	training's profit: 710	valid_1's binary_logloss: 0.027142	valid_1's profit: 95
# [54]	training's binary_logloss: 0.0137269	training's profit: 710	valid_1's binary_logloss: 0.0271008	valid_1's profit: 95
# [55]	training's binary_logloss: 0.0133675	training's profit: 710	valid_1's binary_logloss: 0.0267103	valid_1's profit: 95
# [56]	training's binary_logloss: 0.0130564	training's profit: 710	valid_1's binary_logloss: 0.0263965	valid_1's profit: 95
# [57]	training's binary_logloss: 0.0128197	training's profit: 710	valid_1's binary_logloss: 0.0260138	valid_1's profit: 95
# [58]	training's binary_logloss: 0.0126078	training's profit: 710	valid_1's binary_logloss: 0.0254625	valid_1's profit: 95
# [59]	training's binary_logloss: 0.0124109	training's profit: 710	valid_1's binary_logloss: 0.0251713	valid_1's profit: 95
# [60]	training's binary_logloss: 0.0122289	training's profit: 710	valid_1's binary_logloss: 0.0246297	valid_1's profit: 95
# [61]	training's binary_logloss: 0.0120183	training's profit: 710	valid_1's binary_logloss: 0.0244883	valid_1's profit: 95
# [62]	training's binary_logloss: 0.0118193	training's profit: 710	valid_1's binary_logloss: 0.0240774	valid_1's profit: 95
# [63]	training's binary_logloss: 0.0116112	training's profit: 710	valid_1's binary_logloss: 0.0238633	valid_1's profit: 95
# [64]	training's binary_logloss: 0.0114396	training's profit: 710	valid_1's binary_logloss: 0.0235054	valid_1's profit: 95
# [65]	training's binary_logloss: 0.0112817	training's profit: 710	valid_1's binary_logloss: 0.0233594	valid_1's profit: 95
# [66]	training's binary_logloss: 0.0111491	training's profit: 710	valid_1's binary_logloss: 0.0232424	valid_1's profit: 95
# [67]	training's binary_logloss: 0.011028	training's profit: 710	valid_1's binary_logloss: 0.02293	valid_1's profit: 95
# [68]	training's binary_logloss: 0.0108339	training's profit: 710	valid_1's binary_logloss: 0.0227565	valid_1's profit: 95
# [69]	training's binary_logloss: 0.0107079	training's profit: 710	valid_1's binary_logloss: 0.0226052	valid_1's profit: 95
# [70]	training's binary_logloss: 0.0105685	training's profit: 710	valid_1's binary_logloss: 0.0224314	valid_1's profit: 95
# [71]	training's binary_logloss: 0.0104557	training's profit: 710	valid_1's binary_logloss: 0.02232	valid_1's profit: 95
# [72]	training's binary_logloss: 0.0103697	training's profit: 710	valid_1's binary_logloss: 0.0222364	valid_1's profit: 95
# [73]	training's binary_logloss: 0.0102387	training's profit: 710	valid_1's binary_logloss: 0.0221767	valid_1's profit: 95
# [74]	training's binary_logloss: 0.0101279	training's profit: 710	valid_1's binary_logloss: 0.0219171	valid_1's profit: 95
# [75]	training's binary_logloss: 0.00998374	training's profit: 710	valid_1's binary_logloss: 0.0218224	valid_1's profit: 95
# [76]	training's binary_logloss: 0.00987298	training's profit: 710	valid_1's binary_logloss: 0.0217796	valid_1's profit: 95
# [77]	training's binary_logloss: 0.00977913	training's profit: 710	valid_1's binary_logloss: 0.0214594	valid_1's profit: 95
# [78]	training's binary_logloss: 0.00968483	training's profit: 710	valid_1's binary_logloss: 0.0214974	valid_1's profit: 95
# [79]	training's binary_logloss: 0.00959972	training's profit: 710	valid_1's binary_logloss: 0.0212015	valid_1's profit: 95
# [80]	training's binary_logloss: 0.00948423	training's profit: 710	valid_1's binary_logloss: 0.0212566	valid_1's profit: 95
# [81]	training's binary_logloss: 0.00938675	training's profit: 710	valid_1's binary_logloss: 0.0208836	valid_1's profit: 95
# [82]	training's binary_logloss: 0.00930531	training's profit: 710	valid_1's binary_logloss: 0.0209022	valid_1's profit: 95
# [83]	training's binary_logloss: 0.00924219	training's profit: 710	valid_1's binary_logloss: 0.0206693	valid_1's profit: 95
# [84]	training's binary_logloss: 0.00917256	training's profit: 710	valid_1's binary_logloss: 0.0207234	valid_1's profit: 95
# [85]	training's binary_logloss: 0.00908305	training's profit: 710	valid_1's binary_logloss: 0.0204391	valid_1's profit: 95
# [86]	training's binary_logloss: 0.00901322	training's profit: 710	valid_1's binary_logloss: 0.0202224	valid_1's profit: 95
# [87]	training's binary_logloss: 0.00893852	training's profit: 710	valid_1's binary_logloss: 0.020174	valid_1's profit: 95
# [88]	training's binary_logloss: 0.00886857	training's profit: 710	valid_1's binary_logloss: 0.0202479	valid_1's profit: 95
# [89]	training's binary_logloss: 0.00880692	training's profit: 710	valid_1's binary_logloss: 0.0202278	valid_1's profit: 95
# [90]	training's binary_logloss: 0.00875631	training's profit: 710	valid_1's binary_logloss: 0.0202842	valid_1's profit: 95
# [91]	training's binary_logloss: 0.00869123	training's profit: 710	valid_1's binary_logloss: 0.0199641	valid_1's profit: 95
# [92]	training's binary_logloss: 0.0086215	training's profit: 710	valid_1's binary_logloss: 0.0199251	valid_1's profit: 95
# [93]	training's binary_logloss: 0.00856489	training's profit: 710	valid_1's binary_logloss: 0.0198799	valid_1's profit: 95
# [94]	training's binary_logloss: 0.00847238	training's profit: 710	valid_1's binary_logloss: 0.0199354	valid_1's profit: 95
# [95]	training's binary_logloss: 0.00843587	training's profit: 710	valid_1's binary_logloss: 0.01996	valid_1's profit: 95
# [96]	training's binary_logloss: 0.0083901	training's profit: 710	valid_1's binary_logloss: 0.0199472	valid_1's profit: 95
# [97]	training's binary_logloss: 0.00833288	training's profit: 710	valid_1's binary_logloss: 0.0196805	valid_1's profit: 95
# [98]	training's binary_logloss: 0.00827769	training's profit: 710	valid_1's binary_logloss: 0.0193921	valid_1's profit: 95
# [99]	training's binary_logloss: 0.00820864	training's profit: 710	valid_1's binary_logloss: 0.0192165	valid_1's profit: 95
# [100]	training's binary_logloss: 0.00813405	training's profit: 710	valid_1's binary_logloss: 0.0193166	valid_1's profit: 95
# [101]	training's binary_logloss: 0.00807175	training's profit: 710	valid_1's binary_logloss: 0.0191427	valid_1's profit: 95
# [102]	training's binary_logloss: 0.00803338	training's profit: 710	valid_1's binary_logloss: 0.0189465	valid_1's profit: 95
# [103]	training's binary_logloss: 0.00797351	training's profit: 710	valid_1's binary_logloss: 0.0190174	valid_1's profit: 95
# [104]	training's binary_logloss: 0.00792258	training's profit: 710	valid_1's binary_logloss: 0.0189964	valid_1's profit: 95
# [105]	training's binary_logloss: 0.00788201	training's profit: 710	valid_1's binary_logloss: 0.018786	valid_1's profit: 95
# [106]	training's binary_logloss: 0.00785111	training's profit: 710	valid_1's binary_logloss: 0.018624	valid_1's profit: 95
# [107]	training's binary_logloss: 0.00778732	training's profit: 710	valid_1's binary_logloss: 0.0186373	valid_1's profit: 95
# [108]	training's binary_logloss: 0.00773574	training's profit: 710	valid_1's binary_logloss: 0.0185254	valid_1's profit: 95
# [109]	training's binary_logloss: 0.00769295	training's profit: 710	valid_1's binary_logloss: 0.0186118	valid_1's profit: 95
# [110]	training's binary_logloss: 0.00766216	training's profit: 710	valid_1's binary_logloss: 0.0186094	valid_1's profit: 95
# [111]	training's binary_logloss: 0.00762249	training's profit: 710	valid_1's binary_logloss: 0.0185661	valid_1's profit: 95
# [112]	training's binary_logloss: 0.00757627	training's profit: 710	valid_1's binary_logloss: 0.018591	valid_1's profit: 95
# [113]	training's binary_logloss: 0.00753532	training's profit: 710	valid_1's binary_logloss: 0.0183687	valid_1's profit: 95
# [114]	training's binary_logloss: 0.00748139	training's profit: 710	valid_1's binary_logloss: 0.0183953	valid_1's profit: 95
# [115]	training's binary_logloss: 0.0074395	training's profit: 710	valid_1's binary_logloss: 0.0185123	valid_1's profit: 95
# [116]	training's binary_logloss: 0.00738368	training's profit: 710	valid_1's binary_logloss: 0.0185212	valid_1's profit: 95
# [117]	training's binary_logloss: 0.00735291	training's profit: 710	valid_1's binary_logloss: 0.0183433	valid_1's profit: 95
# [118]	training's binary_logloss: 0.00732778	training's profit: 710	valid_1's binary_logloss: 0.0181938	valid_1's profit: 95
# [119]	training's binary_logloss: 0.00729376	training's profit: 710	valid_1's binary_logloss: 0.0182697	valid_1's profit: 95
# [120]	training's binary_logloss: 0.00724729	training's profit: 710	valid_1's binary_logloss: 0.0183105	valid_1's profit: 95
# [121]	training's binary_logloss: 0.00720201	training's profit: 710	valid_1's binary_logloss: 0.0182983	valid_1's profit: 95
# [122]	training's binary_logloss: 0.00716096	training's profit: 710	valid_1's binary_logloss: 0.0181054	valid_1's profit: 95
# [123]	training's binary_logloss: 0.0071308	training's profit: 710	valid_1's binary_logloss: 0.0181868	valid_1's profit: 95
# [124]	training's binary_logloss: 0.00709732	training's profit: 710	valid_1's binary_logloss: 0.0181127	valid_1's profit: 95
# [125]	training's binary_logloss: 0.00706706	training's profit: 710	valid_1's binary_logloss: 0.0180159	valid_1's profit: 95
# [126]	training's binary_logloss: 0.00703832	training's profit: 710	valid_1's binary_logloss: 0.0178884	valid_1's profit: 95
# [127]	training's binary_logloss: 0.00700562	training's profit: 710	valid_1's binary_logloss: 0.0178888	valid_1's profit: 95
# [128]	training's binary_logloss: 0.00697106	training's profit: 710	valid_1's binary_logloss: 0.0179184	valid_1's profit: 95
# [129]	training's binary_logloss: 0.00694395	training's profit: 710	valid_1's binary_logloss: 0.0177649	valid_1's profit: 95
# [130]	training's binary_logloss: 0.00690663	training's profit: 710	valid_1's binary_logloss: 0.0178218	valid_1's profit: 95
# [131]	training's binary_logloss: 0.00687266	training's profit: 710	valid_1's binary_logloss: 0.0177662	valid_1's profit: 95
# [132]	training's binary_logloss: 0.00684693	training's profit: 710	valid_1's binary_logloss: 0.0176099	valid_1's profit: 95
# [133]	training's binary_logloss: 0.00682336	training's profit: 710	valid_1's binary_logloss: 0.0174858	valid_1's profit: 95
# [134]	training's binary_logloss: 0.00680107	training's profit: 710	valid_1's binary_logloss: 0.0174833	valid_1's profit: 95
# [135]	training's binary_logloss: 0.00676641	training's profit: 710	valid_1's binary_logloss: 0.0174499	valid_1's profit: 95
# [136]	training's binary_logloss: 0.00674682	training's profit: 710	valid_1's binary_logloss: 0.0173328	valid_1's profit: 95
# [137]	training's binary_logloss: 0.00672578	training's profit: 710	valid_1's binary_logloss: 0.0173794	valid_1's profit: 95
# [138]	training's binary_logloss: 0.006702	training's profit: 710	valid_1's binary_logloss: 0.0173793	valid_1's profit: 95
# [139]	training's binary_logloss: 0.00666634	training's profit: 710	valid_1's binary_logloss: 0.0173724	valid_1's profit: 95
# [140]	training's binary_logloss: 0.00664516	training's profit: 710	valid_1's binary_logloss: 0.0172204	valid_1's profit: 95
# [141]	training's binary_logloss: 0.00662572	training's profit: 710	valid_1's binary_logloss: 0.0172174	valid_1's profit: 95
# [142]	training's binary_logloss: 0.00660943	training's profit: 710	valid_1's binary_logloss: 0.017244	valid_1's profit: 95
# [143]	training's binary_logloss: 0.00659077	training's profit: 710	valid_1's binary_logloss: 0.0171035	valid_1's profit: 95
# [144]	training's binary_logloss: 0.00657793	training's profit: 710	valid_1's binary_logloss: 0.0171236	valid_1's profit: 95
# [145]	training's binary_logloss: 0.00655837	training's profit: 710	valid_1's binary_logloss: 0.0171258	valid_1's profit: 95
# [146]	training's binary_logloss: 0.00653443	training's profit: 710	valid_1's binary_logloss: 0.0170709	valid_1's profit: 95
# [147]	training's binary_logloss: 0.00651133	training's profit: 710	valid_1's binary_logloss: 0.0170724	valid_1's profit: 95
# [148]	training's binary_logloss: 0.00648283	training's profit: 710	valid_1's binary_logloss: 0.0169276	valid_1's profit: 95
# [149]	training's binary_logloss: 0.006461	training's profit: 710	valid_1's binary_logloss: 0.0168787	valid_1's profit: 95
# [150]	training's binary_logloss: 0.00644373	training's profit: 710	valid_1's binary_logloss: 0.0169217	valid_1's profit: 95
# [151]	training's binary_logloss: 0.00642591	training's profit: 710	valid_1's binary_logloss: 0.0168644	valid_1's profit: 95
# [152]	training's binary_logloss: 0.00641044	training's profit: 710	valid_1's binary_logloss: 0.0168836	valid_1's profit: 95
# [153]	training's binary_logloss: 0.00639366	training's profit: 710	valid_1's binary_logloss: 0.0167777	valid_1's profit: 95
# [154]	training's binary_logloss: 0.00636289	training's profit: 710	valid_1's binary_logloss: 0.0167767	valid_1's profit: 95
# [155]	training's binary_logloss: 0.00635118	training's profit: 710	valid_1's binary_logloss: 0.0167873	valid_1's profit: 95
# [156]	training's binary_logloss: 0.00633424	training's profit: 710	valid_1's binary_logloss: 0.0166557	valid_1's profit: 95
# [157]	training's binary_logloss: 0.00631266	training's profit: 710	valid_1's binary_logloss: 0.016627	valid_1's profit: 95
# [158]	training's binary_logloss: 0.00629837	training's profit: 710	valid_1's binary_logloss: 0.0166737	valid_1's profit: 95
# [159]	training's binary_logloss: 0.00628227	training's profit: 710	valid_1's binary_logloss: 0.0165461	valid_1's profit: 95
# [160]	training's binary_logloss: 0.00626375	training's profit: 710	valid_1's binary_logloss: 0.0165329	valid_1's profit: 95
# [161]	training's binary_logloss: 0.00624816	training's profit: 710	valid_1's binary_logloss: 0.0165932	valid_1's profit: 95
# [162]	training's binary_logloss: 0.00623253	training's profit: 710	valid_1's binary_logloss: 0.0165482	valid_1's profit: 95
# [163]	training's binary_logloss: 0.00621204	training's profit: 710	valid_1's binary_logloss: 0.0165227	valid_1's profit: 95
# [164]	training's binary_logloss: 0.00620154	training's profit: 710	valid_1's binary_logloss: 0.0164522	valid_1's profit: 95
# [165]	training's binary_logloss: 0.00618579	training's profit: 710	valid_1's binary_logloss: 0.0163266	valid_1's profit: 95
# [166]	training's binary_logloss: 0.00617078	training's profit: 710	valid_1's binary_logloss: 0.0163268	valid_1's profit: 95
# [167]	training's binary_logloss: 0.00615268	training's profit: 710	valid_1's binary_logloss: 0.0163042	valid_1's profit: 95
# [168]	training's binary_logloss: 0.00614202	training's profit: 710	valid_1's binary_logloss: 0.016272	valid_1's profit: 95
# [169]	training's binary_logloss: 0.00612692	training's profit: 710	valid_1's binary_logloss: 0.0161738	valid_1's profit: 95
# [170]	training's binary_logloss: 0.00611716	training's profit: 710	valid_1's binary_logloss: 0.0161836	valid_1's profit: 95
# [171]	training's binary_logloss: 0.00610309	training's profit: 710	valid_1's binary_logloss: 0.0161432	valid_1's profit: 95
# [172]	training's binary_logloss: 0.00608858	training's profit: 710	valid_1's binary_logloss: 0.0161257	valid_1's profit: 95
# [173]	training's binary_logloss: 0.0060715	training's profit: 710	valid_1's binary_logloss: 0.0161257	valid_1's profit: 95
# [174]	training's binary_logloss: 0.00605823	training's profit: 710	valid_1's binary_logloss: 0.0161264	valid_1's profit: 95
# [175]	training's binary_logloss: 0.00604594	training's profit: 710	valid_1's binary_logloss: 0.0161308	valid_1's profit: 95
# [176]	training's binary_logloss: 0.00603202	training's profit: 710	valid_1's binary_logloss: 0.0160401	valid_1's profit: 95
# [177]	training's binary_logloss: 0.0060178	training's profit: 710	valid_1's binary_logloss: 0.016076	valid_1's profit: 95
# [178]	training's binary_logloss: 0.00600888	training's profit: 710	valid_1's binary_logloss: 0.0160051	valid_1's profit: 95
# [179]	training's binary_logloss: 0.00599572	training's profit: 710	valid_1's binary_logloss: 0.0158947	valid_1's profit: 95
# [180]	training's binary_logloss: 0.00598315	training's profit: 710	valid_1's binary_logloss: 0.0158991	valid_1's profit: 95
# [181]	training's binary_logloss: 0.00597014	training's profit: 710	valid_1's binary_logloss: 0.015894	valid_1's profit: 95
# [182]	training's binary_logloss: 0.00595322	training's profit: 710	valid_1's binary_logloss: 0.0158571	valid_1's profit: 95
# [183]	training's binary_logloss: 0.00593855	training's profit: 710	valid_1's binary_logloss: 0.0158569	valid_1's profit: 95
# [184]	training's binary_logloss: 0.0059268	training's profit: 710	valid_1's binary_logloss: 0.0158202	valid_1's profit: 95
# [185]	training's binary_logloss: 0.00591862	training's profit: 710	valid_1's binary_logloss: 0.0157534	valid_1's profit: 95
# [186]	training's binary_logloss: 0.00590672	training's profit: 710	valid_1's binary_logloss: 0.0156508	valid_1's profit: 95
# [187]	training's binary_logloss: 0.00589292	training's profit: 710	valid_1's binary_logloss: 0.0156488	valid_1's profit: 95
# [188]	training's binary_logloss: 0.00587717	training's profit: 710	valid_1's binary_logloss: 0.0156282	valid_1's profit: 95
# [189]	training's binary_logloss: 0.00586577	training's profit: 710	valid_1's binary_logloss: 0.0155281	valid_1's profit: 95
# [190]	training's binary_logloss: 0.00585432	training's profit: 710	valid_1's binary_logloss: 0.0155576	valid_1's profit: 95
# [191]	training's binary_logloss: 0.00584291	training's profit: 710	valid_1's binary_logloss: 0.0156124	valid_1's profit: 95
# [192]	training's binary_logloss: 0.00582194	training's profit: 710	valid_1's binary_logloss: 0.0155943	valid_1's profit: 95
# [193]	training's binary_logloss: 0.00581059	training's profit: 710	valid_1's binary_logloss: 0.0154945	valid_1's profit: 95
# [194]	training's binary_logloss: 0.00579688	training's profit: 710	valid_1's binary_logloss: 0.0154783	valid_1's profit: 95
# [195]	training's binary_logloss: 0.00578524	training's profit: 710	valid_1's binary_logloss: 0.0154826	valid_1's profit: 95
# [196]	training's binary_logloss: 0.00577054	training's profit: 710	valid_1's binary_logloss: 0.0154513	valid_1's profit: 95
# [197]	training's binary_logloss: 0.00576278	training's profit: 710	valid_1's binary_logloss: 0.0154577	valid_1's profit: 95
# [198]	training's binary_logloss: 0.00575614	training's profit: 710	valid_1's binary_logloss: 0.0153748	valid_1's profit: 95
# [199]	training's binary_logloss: 0.00574628	training's profit: 710	valid_1's binary_logloss: 0.0153603	valid_1's profit: 95
# [200]	training's binary_logloss: 0.0057359	training's profit: 710	valid_1's binary_logloss: 0.0152655	valid_1's profit: 95
# [201]	training's binary_logloss: 0.00572567	training's profit: 710	valid_1's binary_logloss: 0.0152936	valid_1's profit: 95
# [202]	training's binary_logloss: 0.00571453	training's profit: 710	valid_1's binary_logloss: 0.0153243	valid_1's profit: 95
# [203]	training's binary_logloss: 0.00570423	training's profit: 710	valid_1's binary_logloss: 0.0152297	valid_1's profit: 95
# [204]	training's binary_logloss: 0.00569107	training's profit: 710	valid_1's binary_logloss: 0.0152016	valid_1's profit: 95
# [205]	training's binary_logloss: 0.00567494	training's profit: 710	valid_1's binary_logloss: 0.0151895	valid_1's profit: 95
# [206]	training's binary_logloss: 0.00566348	training's profit: 710	valid_1's binary_logloss: 0.0151791	valid_1's profit: 95
# [207]	training's binary_logloss: 0.0056567	training's profit: 710	valid_1's binary_logloss: 0.0152208	valid_1's profit: 95
# [208]	training's binary_logloss: 0.00564774	training's profit: 710	valid_1's binary_logloss: 0.0151327	valid_1's profit: 95
# [209]	training's binary_logloss: 0.00563838	training's profit: 710	valid_1's binary_logloss: 0.0151661	valid_1's profit: 95
# [210]	training's binary_logloss: 0.00563146	training's profit: 710	valid_1's binary_logloss: 0.0151353	valid_1's profit: 95
# [211]	training's binary_logloss: 0.00562155	training's profit: 710	valid_1's binary_logloss: 0.0150993	valid_1's profit: 95
# [212]	training's binary_logloss: 0.00561083	training's profit: 710	valid_1's binary_logloss: 0.0150968	valid_1's profit: 95
# [213]	training's binary_logloss: 0.00560099	training's profit: 710	valid_1's binary_logloss: 0.0150876	valid_1's profit: 95
# [214]	training's binary_logloss: 0.0055894	training's profit: 710	valid_1's binary_logloss: 0.0151064	valid_1's profit: 95
# [215]	training's binary_logloss: 0.00558283	training's profit: 710	valid_1's binary_logloss: 0.0150763	valid_1's profit: 95
# [216]	training's binary_logloss: 0.0055768	training's profit: 710	valid_1's binary_logloss: 0.015	valid_1's profit: 95
# [217]	training's binary_logloss: 0.00557098	training's profit: 710	valid_1's binary_logloss: 0.014932	valid_1's profit: 95
# [218]	training's binary_logloss: 0.00556229	training's profit: 710	valid_1's binary_logloss: 0.0149583	valid_1's profit: 95
# [219]	training's binary_logloss: 0.00555115	training's profit: 710	valid_1's binary_logloss: 0.014961	valid_1's profit: 95
# [220]	training's binary_logloss: 0.00554575	training's profit: 710	valid_1's binary_logloss: 0.0148964	valid_1's profit: 95
# [221]	training's binary_logloss: 0.00553583	training's profit: 710	valid_1's binary_logloss: 0.0149021	valid_1's profit: 95
# [222]	training's binary_logloss: 0.00552947	training's profit: 710	valid_1's binary_logloss: 0.0148803	valid_1's profit: 95
# [223]	training's binary_logloss: 0.00552021	training's profit: 710	valid_1's binary_logloss: 0.014872	valid_1's profit: 95
# [224]	training's binary_logloss: 0.00551505	training's profit: 710	valid_1's binary_logloss: 0.014809	valid_1's profit: 95
# [225]	training's binary_logloss: 0.00550734	training's profit: 710	valid_1's binary_logloss: 0.0148337	valid_1's profit: 95
# [226]	training's binary_logloss: 0.00549167	training's profit: 710	valid_1's binary_logloss: 0.0148924	valid_1's profit: 95
# [227]	training's binary_logloss: 0.00548411	training's profit: 710	valid_1's binary_logloss: 0.0148709	valid_1's profit: 95
# [228]	training's binary_logloss: 0.00547915	training's profit: 710	valid_1's binary_logloss: 0.0148094	valid_1's profit: 95
# [229]	training's binary_logloss: 0.00546818	training's profit: 710	valid_1's binary_logloss: 0.0147918	valid_1's profit: 95
# [230]	training's binary_logloss: 0.00546041	training's profit: 710	valid_1's binary_logloss: 0.0147356	valid_1's profit: 95
# [231]	training's binary_logloss: 0.00545676	training's profit: 710	valid_1's binary_logloss: 0.0146969	valid_1's profit: 95
# [232]	training's binary_logloss: 0.00544754	training's profit: 710	valid_1's binary_logloss: 0.0147032	valid_1's profit: 95
# [233]	training's binary_logloss: 0.00544185	training's profit: 710	valid_1's binary_logloss: 0.0146764	valid_1's profit: 95
# [234]	training's binary_logloss: 0.00543158	training's profit: 710	valid_1's binary_logloss: 0.0146896	valid_1's profit: 95
# [235]	training's binary_logloss: 0.00542695	training's profit: 710	valid_1's binary_logloss: 0.014631	valid_1's profit: 95
# [236]	training's binary_logloss: 0.00541887	training's profit: 710	valid_1's binary_logloss: 0.0146243	valid_1's profit: 95
# [237]	training's binary_logloss: 0.00541451	training's profit: 710	valid_1's binary_logloss: 0.0145677	valid_1's profit: 95
# [238]	training's binary_logloss: 0.00540574	training's profit: 710	valid_1's binary_logloss: 0.0145948	valid_1's profit: 95
# [239]	training's binary_logloss: 0.00540253	training's profit: 710	valid_1's binary_logloss: 0.0145592	valid_1's profit: 95
# [240]	training's binary_logloss: 0.00539683	training's profit: 710	valid_1's binary_logloss: 0.014539	valid_1's profit: 95
# [241]	training's binary_logloss: 0.00539123	training's profit: 710	valid_1's binary_logloss: 0.0145515	valid_1's profit: 95
# [242]	training's binary_logloss: 0.00538442	training's profit: 710	valid_1's binary_logloss: 0.0145746	valid_1's profit: 95
# [243]	training's binary_logloss: 0.00538022	training's profit: 710	valid_1's binary_logloss: 0.0145202	valid_1's profit: 95
# [244]	training's binary_logloss: 0.0053709	training's profit: 710	valid_1's binary_logloss: 0.0145058	valid_1's profit: 95
# [245]	training's binary_logloss: 0.00536762	training's profit: 710	valid_1's binary_logloss: 0.0145363	valid_1's profit: 95
# [246]	training's binary_logloss: 0.00536242	training's profit: 710	valid_1's binary_logloss: 0.0145176	valid_1's profit: 95
# [247]	training's binary_logloss: 0.00535085	training's profit: 710	valid_1's binary_logloss: 0.0145377	valid_1's profit: 95
# [248]	training's binary_logloss: 0.00534769	training's profit: 710	valid_1's binary_logloss: 0.0145026	valid_1's profit: 95
# [249]	training's binary_logloss: 0.00534452	training's profit: 710	valid_1's binary_logloss: 0.0145328	valid_1's profit: 95
# [250]	training's binary_logloss: 0.00533484	training's profit: 710	valid_1's binary_logloss: 0.0145368	valid_1's profit: 95
# [251]	training's binary_logloss: 0.00532687	training's profit: 710	valid_1's binary_logloss: 0.0145415	valid_1's profit: 95
# [252]	training's binary_logloss: 0.00531556	training's profit: 710	valid_1's binary_logloss: 0.0145244	valid_1's profit: 95
# [253]	training's binary_logloss: 0.00530873	training's profit: 710	valid_1's binary_logloss: 0.0144717	valid_1's profit: 95
# [254]	training's binary_logloss: 0.00530557	training's profit: 710	valid_1's binary_logloss: 0.0144368	valid_1's profit: 95
# [255]	training's binary_logloss: 0.00529815	training's profit: 710	valid_1's binary_logloss: 0.0144317	valid_1's profit: 95
# [256]	training's binary_logloss: 0.00529515	training's profit: 710	valid_1's binary_logloss: 0.0143977	valid_1's profit: 95
# [257]	training's binary_logloss: 0.00528993	training's profit: 710	valid_1's binary_logloss: 0.0144132	valid_1's profit: 95
# [258]	training's binary_logloss: 0.00528229	training's profit: 710	valid_1's binary_logloss: 0.0144183	valid_1's profit: 95
# [259]	training's binary_logloss: 0.00527363	training's profit: 710	valid_1's binary_logloss: 0.0144046	valid_1's profit: 95
# [260]	training's binary_logloss: 0.00527056	training's profit: 710	valid_1's binary_logloss: 0.0144348	valid_1's profit: 95
# [261]	training's binary_logloss: 0.00526174	training's profit: 710	valid_1's binary_logloss: 0.0144386	valid_1's profit: 95
# [262]	training's binary_logloss: 0.0052589	training's profit: 710	valid_1's binary_logloss: 0.0144059	valid_1's profit: 95
# [263]	training's binary_logloss: 0.00524852	training's profit: 710	valid_1's binary_logloss: 0.0143901	valid_1's profit: 95
# [264]	training's binary_logloss: 0.00524213	training's profit: 710	valid_1's binary_logloss: 0.0144123	valid_1's profit: 95
# [265]	training's binary_logloss: 0.0052393	training's profit: 710	valid_1's binary_logloss: 0.0143797	valid_1's profit: 95
# [266]	training's binary_logloss: 0.00523437	training's profit: 710	valid_1's binary_logloss: 0.0143415	valid_1's profit: 95
# [267]	training's binary_logloss: 0.00522667	training's profit: 710	valid_1's binary_logloss: 0.0143771	valid_1's profit: 95
# [268]	training's binary_logloss: 0.00522181	training's profit: 710	valid_1's binary_logloss: 0.014392	valid_1's profit: 95
# [269]	training's binary_logloss: 0.00521488	training's profit: 710	valid_1's binary_logloss: 0.0144063	valid_1's profit: 95
# [270]	training's binary_logloss: 0.00521201	training's profit: 710	valid_1's binary_logloss: 0.0143734	valid_1's profit: 95
# [271]	training's binary_logloss: 0.00520393	training's profit: 710	valid_1's binary_logloss: 0.0143602	valid_1's profit: 95
# [272]	training's binary_logloss: 0.00520092	training's profit: 710	valid_1's binary_logloss: 0.0143906	valid_1's profit: 95
# [273]	training's binary_logloss: 0.00519835	training's profit: 710	valid_1's binary_logloss: 0.01436	valid_1's profit: 95
# [274]	training's binary_logloss: 0.00519161	training's profit: 710	valid_1's binary_logloss: 0.014355	valid_1's profit: 95
# [275]	training's binary_logloss: 0.00518778	training's profit: 710	valid_1's binary_logloss: 0.0143342	valid_1's profit: 95
# [276]	training's binary_logloss: 0.00518512	training's profit: 710	valid_1's binary_logloss: 0.0143029	valid_1's profit: 95
# [277]	training's binary_logloss: 0.00518251	training's profit: 710	valid_1's binary_logloss: 0.0143309	valid_1's profit: 95
# [278]	training's binary_logloss: 0.00517509	training's profit: 710	valid_1's binary_logloss: 0.0143431	valid_1's profit: 95
# [279]	training's binary_logloss: 0.00516417	training's profit: 710	valid_1's binary_logloss: 0.0143648	valid_1's profit: 95
# [280]	training's binary_logloss: 0.00515619	training's profit: 710	valid_1's binary_logloss: 0.0143667	valid_1's profit: 95
# [281]	training's binary_logloss: 0.00515357	training's profit: 710	valid_1's binary_logloss: 0.0143356	valid_1's profit: 95
# [282]	training's binary_logloss: 0.0051478	training's profit: 710	valid_1's binary_logloss: 0.0142887	valid_1's profit: 95
# [283]	training's binary_logloss: 0.00514513	training's profit: 710	valid_1's binary_logloss: 0.0143173	valid_1's profit: 95
# [284]	training's binary_logloss: 0.00513533	training's profit: 710	valid_1's binary_logloss: 0.014339	valid_1's profit: 95
# [285]	training's binary_logloss: 0.00513004	training's profit: 710	valid_1's binary_logloss: 0.0142963	valid_1's profit: 95
# [286]	training's binary_logloss: 0.00512721	training's profit: 710	valid_1's binary_logloss: 0.0143259	valid_1's profit: 95
# [287]	training's binary_logloss: 0.00511959	training's profit: 710	valid_1's binary_logloss: 0.0143189	valid_1's profit: 95
# [288]	training's binary_logloss: 0.00511682	training's profit: 710	valid_1's binary_logloss: 0.0142869	valid_1's profit: 95
# [289]	training's binary_logloss: 0.00511166	training's profit: 710	valid_1's binary_logloss: 0.0143168	valid_1's profit: 95
# [290]	training's binary_logloss: 0.00510895	training's profit: 710	valid_1's binary_logloss: 0.0142853	valid_1's profit: 95
# [291]	training's binary_logloss: 0.00510172	training's profit: 710	valid_1's binary_logloss: 0.0142676	valid_1's profit: 95
# [292]	training's binary_logloss: 0.00509582	training's profit: 710	valid_1's binary_logloss: 0.0142854	valid_1's profit: 95
# [293]	training's binary_logloss: 0.00509137	training's profit: 710	valid_1's binary_logloss: 0.014268	valid_1's profit: 95
# [294]	training's binary_logloss: 0.00508862	training's profit: 710	valid_1's binary_logloss: 0.0142362	valid_1's profit: 95
# [295]	training's binary_logloss: 0.00508627	training's profit: 710	valid_1's binary_logloss: 0.0142628	valid_1's profit: 95
# [296]	training's binary_logloss: 0.00508397	training's profit: 710	valid_1's binary_logloss: 0.0142344	valid_1's profit: 95
# [297]	training's binary_logloss: 0.00507974	training's profit: 710	valid_1's binary_logloss: 0.0142006	valid_1's profit: 95
# [298]	training's binary_logloss: 0.00507435	training's profit: 710	valid_1's binary_logloss: 0.0142211	valid_1's profit: 95
# [299]	training's binary_logloss: 0.00506754	training's profit: 710	valid_1's binary_logloss: 0.0142107	valid_1's profit: 95
# [300]	training's binary_logloss: 0.00506506	training's profit: 710	valid_1's binary_logloss: 0.0142384	valid_1's profit: 95
# [301]	training's binary_logloss: 0.00505965	training's profit: 710	valid_1's binary_logloss: 0.0142541	valid_1's profit: 95
# [302]	training's binary_logloss: 0.00505721	training's profit: 710	valid_1's binary_logloss: 0.014225	valid_1's profit: 95
# [303]	training's binary_logloss: 0.00505259	training's profit: 710	valid_1's binary_logloss: 0.014253	valid_1's profit: 95
# [304]	training's binary_logloss: 0.0050502	training's profit: 710	valid_1's binary_logloss: 0.0142244	valid_1's profit: 95
# [305]	training's binary_logloss: 0.00504371	training's profit: 710	valid_1's binary_logloss: 0.0142085	valid_1's profit: 95
# [306]	training's binary_logloss: 0.00504153	training's profit: 710	valid_1's binary_logloss: 0.0141814	valid_1's profit: 95
# [307]	training's binary_logloss: 0.00503145	training's profit: 710	valid_1's binary_logloss: 0.0141951	valid_1's profit: 95
# [308]	training's binary_logloss: 0.0050271	training's profit: 710	valid_1's binary_logloss: 0.0141784	valid_1's profit: 95
# [309]	training's binary_logloss: 0.00502265	training's profit: 710	valid_1's binary_logloss: 0.0141986	valid_1's profit: 95
# [310]	training's binary_logloss: 0.00501896	training's profit: 710	valid_1's binary_logloss: 0.0141679	valid_1's profit: 95
# [311]	training's binary_logloss: 0.00501664	training's profit: 710	valid_1's binary_logloss: 0.0141951	valid_1's profit: 95
# [312]	training's binary_logloss: 0.00500716	training's profit: 710	valid_1's binary_logloss: 0.0142167	valid_1's profit: 95
# [313]	training's binary_logloss: 0.00500498	training's profit: 710	valid_1's binary_logloss: 0.014243	valid_1's profit: 95
# [314]	training's binary_logloss: 0.00500275	training's profit: 710	valid_1's binary_logloss: 0.0142156	valid_1's profit: 95
# [315]	training's binary_logloss: 0.00499869	training's profit: 710	valid_1's binary_logloss: 0.0141819	valid_1's profit: 95
# [316]	training's binary_logloss: 0.00498449	training's profit: 710	valid_1's binary_logloss: 0.0142579	valid_1's profit: 95
# [317]	training's binary_logloss: 0.00497529	training's profit: 710	valid_1's binary_logloss: 0.0142523	valid_1's profit: 95
# [318]	training's binary_logloss: 0.00497135	training's profit: 710	valid_1's binary_logloss: 0.0142193	valid_1's profit: 95
# [319]	training's binary_logloss: 0.00496716	training's profit: 710	valid_1's binary_logloss: 0.0142456	valid_1's profit: 95
# [320]	training's binary_logloss: 0.00496481	training's profit: 710	valid_1's binary_logloss: 0.0142177	valid_1's profit: 95
# [321]	training's binary_logloss: 0.00495661	training's profit: 710	valid_1's binary_logloss: 0.0142387	valid_1's profit: 95
# [322]	training's binary_logloss: 0.00495212	training's profit: 710	valid_1's binary_logloss: 0.0141988	valid_1's profit: 95
# [323]	training's binary_logloss: 0.00494986	training's profit: 710	valid_1's binary_logloss: 0.014226	valid_1's profit: 95
# [324]	training's binary_logloss: 0.00494353	training's profit: 710	valid_1's binary_logloss: 0.0142317	valid_1's profit: 95
# [325]	training's binary_logloss: 0.00494119	training's profit: 710	valid_1's binary_logloss: 0.0142037	valid_1's profit: 95
# [326]	training's binary_logloss: 0.00493538	training's profit: 710	valid_1's binary_logloss: 0.0141435	valid_1's profit: 95
# [327]	training's binary_logloss: 0.00493233	training's profit: 710	valid_1's binary_logloss: 0.0141617	valid_1's profit: 95
# [328]	training's binary_logloss: 0.004928	training's profit: 710	valid_1's binary_logloss: 0.0141216	valid_1's profit: 95
# [329]	training's binary_logloss: 0.00492591	training's profit: 710	valid_1's binary_logloss: 0.0140959	valid_1's profit: 95
# [330]	training's binary_logloss: 0.00491971	training's profit: 710	valid_1's binary_logloss: 0.0140815	valid_1's profit: 95
# [331]	training's binary_logloss: 0.00491103	training's profit: 710	valid_1's binary_logloss: 0.0141265	valid_1's profit: 95
# [332]	training's binary_logloss: 0.00490911	training's profit: 710	valid_1's binary_logloss: 0.0141024	valid_1's profit: 95
# [333]	training's binary_logloss: 0.00490393	training's profit: 710	valid_1's binary_logloss: 0.0140797	valid_1's profit: 95
# [334]	training's binary_logloss: 0.0048963	training's profit: 710	valid_1's binary_logloss: 0.0141001	valid_1's profit: 95
# [335]	training's binary_logloss: 0.0048921	training's profit: 710	valid_1's binary_logloss: 0.0140622	valid_1's profit: 95
# [336]	training's binary_logloss: 0.00488368	training's profit: 710	valid_1's binary_logloss: 0.0141074	valid_1's profit: 95
# [337]	training's binary_logloss: 0.00488173	training's profit: 710	valid_1's binary_logloss: 0.014083	valid_1's profit: 95
# [338]	training's binary_logloss: 0.00487964	training's profit: 710	valid_1's binary_logloss: 0.0140693	valid_1's profit: 95
# [339]	training's binary_logloss: 0.00487576	training's profit: 710	valid_1's binary_logloss: 0.0140936	valid_1's profit: 95
# [340]	training's binary_logloss: 0.00487006	training's profit: 710	valid_1's binary_logloss: 0.014086	valid_1's profit: 95
# [341]	training's binary_logloss: 0.00486787	training's profit: 710	valid_1's binary_logloss: 0.0140597	valid_1's profit: 95
# [342]	training's binary_logloss: 0.00486587	training's profit: 710	valid_1's binary_logloss: 0.0140852	valid_1's profit: 95
# [343]	training's binary_logloss: 0.00486198	training's profit: 710	valid_1's binary_logloss: 0.0140488	valid_1's profit: 95
# [344]	training's binary_logloss: 0.00486	training's profit: 710	valid_1's binary_logloss: 0.0140243	valid_1's profit: 95
# [345]	training's binary_logloss: 0.00485507	training's profit: 710	valid_1's binary_logloss: 0.0140408	valid_1's profit: 95
# [346]	training's binary_logloss: 0.00485203	training's profit: 710	valid_1's binary_logloss: 0.0140418	valid_1's profit: 95
# [347]	training's binary_logloss: 0.00485012	training's profit: 710	valid_1's binary_logloss: 0.0140177	valid_1's profit: 95
# [348]	training's binary_logloss: 0.0048469	training's profit: 710	valid_1's binary_logloss: 0.0139887	valid_1's profit: 95
# [349]	training's binary_logloss: 0.00484315	training's profit: 710	valid_1's binary_logloss: 0.0140125	valid_1's profit: 95
# [350]	training's binary_logloss: 0.00484139	training's profit: 710	valid_1's binary_logloss: 0.0140363	valid_1's profit: 95
# [351]	training's binary_logloss: 0.00483961	training's profit: 710	valid_1's binary_logloss: 0.0140135	valid_1's profit: 95
# [352]	training's binary_logloss: 0.00483222	training's profit: 710	valid_1's binary_logloss: 0.0140339	valid_1's profit: 95
# [353]	training's binary_logloss: 0.00482674	training's profit: 710	valid_1's binary_logloss: 0.0140265	valid_1's profit: 95
# [354]	training's binary_logloss: 0.00482479	training's profit: 710	valid_1's binary_logloss: 0.0140516	valid_1's profit: 95
# [355]	training's binary_logloss: 0.00482145	training's profit: 710	valid_1's binary_logloss: 0.0140216	valid_1's profit: 95
# [356]	training's binary_logloss: 0.00480939	training's profit: 710	valid_1's binary_logloss: 0.0140945	valid_1's profit: 95
# [357]	training's binary_logloss: 0.00480575	training's profit: 710	valid_1's binary_logloss: 0.0141082	valid_1's profit: 95
# [358]	training's binary_logloss: 0.00480239	training's profit: 710	valid_1's binary_logloss: 0.0141303	valid_1's profit: 95
# [359]	training's binary_logloss: 0.00479518	training's profit: 710	valid_1's binary_logloss: 0.0141273	valid_1's profit: 95
# [360]	training's binary_logloss: 0.00478845	training's profit: 710	valid_1's binary_logloss: 0.0141141	valid_1's profit: 95
# [361]	training's binary_logloss: 0.00478633	training's profit: 710	valid_1's binary_logloss: 0.0140886	valid_1's profit: 95
# [362]	training's binary_logloss: 0.00478454	training's profit: 710	valid_1's binary_logloss: 0.0140657	valid_1's profit: 95
# [363]	training's binary_logloss: 0.0047809	training's profit: 710	valid_1's binary_logloss: 0.01403	valid_1's profit: 95
# [364]	training's binary_logloss: 0.00477765	training's profit: 710	valid_1's binary_logloss: 0.0140518	valid_1's profit: 95
# [365]	training's binary_logloss: 0.00477577	training's profit: 710	valid_1's binary_logloss: 0.0140284	valid_1's profit: 95
# [366]	training's binary_logloss: 0.00477412	training's profit: 710	valid_1's binary_logloss: 0.0140518	valid_1's profit: 95
# [367]	training's binary_logloss: 0.00477253	training's profit: 710	valid_1's binary_logloss: 0.0140309	valid_1's profit: 95
# [368]	training's binary_logloss: 0.00476982	training's profit: 710	valid_1's binary_logloss: 0.0140057	valid_1's profit: 95
# [369]	training's binary_logloss: 0.00476547	training's profit: 710	valid_1's binary_logloss: 0.0140215	valid_1's profit: 95
# [370]	training's binary_logloss: 0.00476077	training's profit: 710	valid_1's binary_logloss: 0.0140322	valid_1's profit: 95
# [371]	training's binary_logloss: 0.00475771	training's profit: 710	valid_1's binary_logloss: 0.0140455	valid_1's profit: 95
# [372]	training's binary_logloss: 0.00474762	training's profit: 710	valid_1's binary_logloss: 0.0141126	valid_1's profit: 95
# [373]	training's binary_logloss: 0.00474599	training's profit: 710	valid_1's binary_logloss: 0.0140914	valid_1's profit: 95
# [374]	training's binary_logloss: 0.00474181	training's profit: 710	valid_1's binary_logloss: 0.0140496	valid_1's profit: 95
# [375]	training's binary_logloss: 0.00473731	training's profit: 710	valid_1's binary_logloss: 0.0140349	valid_1's profit: 95
# [376]	training's binary_logloss: 0.00473471	training's profit: 710	valid_1's binary_logloss: 0.0140112	valid_1's profit: 95
# [377]	training's binary_logloss: 0.00473156	training's profit: 710	valid_1's binary_logloss: 0.0140325	valid_1's profit: 95
# [378]	training's binary_logloss: 0.00472727	training's profit: 710	valid_1's binary_logloss: 0.0140234	valid_1's profit: 95
# [379]	training's binary_logloss: 0.00472566	training's profit: 710	valid_1's binary_logloss: 0.0140321	valid_1's profit: 95
# [380]	training's binary_logloss: 0.00472421	training's profit: 710	valid_1's binary_logloss: 0.0140462	valid_1's profit: 95
# [381]	training's binary_logloss: 0.0047226	training's profit: 710	valid_1's binary_logloss: 0.0140254	valid_1's profit: 95
# [382]	training's binary_logloss: 0.00471974	training's profit: 710	valid_1's binary_logloss: 0.0140145	valid_1's profit: 95
# [383]	training's binary_logloss: 0.00471826	training's profit: 710	valid_1's binary_logloss: 0.013995	valid_1's profit: 95
# [384]	training's binary_logloss: 0.00471417	training's profit: 710	valid_1's binary_logloss: 0.0139592	valid_1's profit: 95
# [385]	training's binary_logloss: 0.00471274	training's profit: 710	valid_1's binary_logloss: 0.0139674	valid_1's profit: 95
# [386]	training's binary_logloss: 0.00471028	training's profit: 710	valid_1's binary_logloss: 0.0139839	valid_1's profit: 95
# [387]	training's binary_logloss: 0.0047075	training's profit: 710	valid_1's binary_logloss: 0.0140036	valid_1's profit: 95
# [388]	training's binary_logloss: 0.00470515	training's profit: 710	valid_1's binary_logloss: 0.0140217	valid_1's profit: 95
# ...
# [473]	training's binary_logloss: 0.00435445	training's profit: 710	valid_1's binary_logloss: 0.017589	valid_1's profit: 80
# [474]	training's binary_logloss: 0.00435445	training's profit: 710	valid_1's binary_logloss: 0.017589	valid_1's profit: 80
# [475]	training's binary_logloss: 0.0043533	training's profit: 710	valid_1's binary_logloss: 0.017589	valid_1's profit: 80
# [476]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [477]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [478]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [479]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [480]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [481]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [482]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [483]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [484]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [485]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [486]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [487]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [488]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [489]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [490]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [491]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [492]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [493]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [494]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [495]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [496]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [497]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [498]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [499]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [500]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [501]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [502]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [503]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [504]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [505]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [506]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [507]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [508]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [509]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [510]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [511]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [512]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [513]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [514]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [515]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [516]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [517]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [518]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [519]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [520]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [521]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [522]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [523]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [524]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [525]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [526]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [527]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [528]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [529]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [530]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [531]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [532]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [533]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [534]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [535]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [536]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [537]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [538]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [539]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [540]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [541]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [542]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [543]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [544]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [545]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [546]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [547]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [548]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [549]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [550]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [551]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [552]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [553]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [554]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [555]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [556]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [557]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [558]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [559]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [560]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [561]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [562]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [563]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [564]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [565]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [566]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [567]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [568]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [569]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [570]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [571]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [572]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [573]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [574]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [575]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [576]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [577]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [578]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [579]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [580]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [581]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [582]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [583]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [584]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [585]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [586]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [587]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [588]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [589]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [590]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [591]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [592]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [593]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [594]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [595]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [596]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [597]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [598]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [599]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# [600]	training's binary_logloss: 0.00435215	training's profit: 710	valid_1's binary_logloss: 0.017582	valid_1's profit: 80
# --------------------------------
# FOLD 5: PROFIT = 90
# --------------------------------
#
# --------------------------------
# TOTAL PROFIT = 375
# --------------------------------

# %%
##### RECHECK PROFIT  
prediction_reward(y, preds_oof)


###### TRACKING RESULTS (5 folds, strat = True, seed = 23)

# V1: lgb, 5 folds, default features:   80
# V2: add feature:  no. total items:   250
# V3: use logloss for ES, not profit:  260
# V4: add feature: no. weird actions:  275
# V5: custom earlystop for profit:     320
# V6: add SMOTE for minority class:    335
# V7: add robust data scaling:         350 = 95 + 55 + 75 + 35 + 90
# V8: increase learning rate to 0.1:   375 = 95 + 65 + 75 + 50 + 90

# %%
##### VARIABLE IMPORTANCE

# load importance    
top_feats = 100
cols = importances[['Feature', 'Importance']].groupby('Feature').mean().sort_values(by = 'Importance', ascending = False)[0:top_feats].index
importance = importances.loc[importances.Feature.isin(cols)]
    
# plot variable importance
plt.figure(figsize = (10, 6))
sns.barplot(x = 'Importance', y = 'Feature', data = importance.sort_values(by = 'Importance', ascending = False))
plt.tight_layout()

# save plot as pdf
plt.savefig('../var_importance.pdf')

# %% [markdown]
# ### CUTOFF OPTIMIZATION

# %%
##### OPTIMIZE CUTOFF

# set step
step = 100

# search
cutoffs = []
profits = []
for i in range(0, step):
    cutoffs.append(i / step)
    profits.append(recompute_reward(y, preds_oof, cutoff = cutoffs[i]))
        
# results
plt.figure(figsize = (10,4))
sns.lineplot(x = cutoffs[10:step], y = profits[10:step], color = 'red')
plt.tight_layout()
plt.axvline(x = cutoffs[np.argmax(profits)], color = 'white', linestyle = '--')
print('- optimal cutoff = %.4f' % cutoffs[np.argmax(profits)])
print('- optimal profit = %.4f' % profits[np.argmax(profits)])
plt.savefig('../cutoff_selection.pdf')

# %% [markdown]
# # 4. SUBMISSION

# %%
# file name
model = 'lgb_v8'
perf  = str(round(cv_perf, 0).astype('int'))
name  = model + '_' + perf

# %%
# export OOF preds
oof = pd.DataFrame({'id': train['id'], 'fraud': preds_oof})
oof.to_csv('../oof_preds/' + str(name) + '.csv', index = False)
oof.head()

# %%
# check submission
sub = pd.DataFrame({'id': test['id'], 'fraud': preds_test})
sub['fraud'] = np.round(sub['fraud']).astype('int')
sub.head()

# %%
# export submission
sub = sub[['fraud']]
sub.to_csv('../submissions/' + str(name) + '.csv', index = False)
sub.shape

# %%
# check correlation with previous submission
prev_sub = pd.read_csv('../submissions/lgb_v8_375.csv')
cor = np.sum(prev_sub[target] == sub.reset_index()[target]) / len(sub)
print("Share of the same predictions: " + str(np.round(cor, 6)))
